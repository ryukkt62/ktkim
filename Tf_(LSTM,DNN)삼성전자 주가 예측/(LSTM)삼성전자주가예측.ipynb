# %% [markdown]
# # 다:1 LSTM모델로 예측

# %%
# !pip install plot-keras-history
# Out:
# Collecting plot-keras-history
#   Downloading plot_keras_history-1.1.38.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from plot-keras-history) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from plot-keras-history) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from plot-keras-history) (1.11.4)
# Collecting support_developer>=1.0.2 (from plot-keras-history)
#   Downloading support_developer-1.0.5.tar.gz (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sanitize_ml_labels>=1.0.48 (from plot-keras-history)
#   Downloading sanitize_ml_labels-1.0.51.tar.gz (322 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.5/322.5 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting compress_json (from sanitize_ml_labels>=1.0.48->plot-keras-history)
#   Downloading compress_json-1.0.10.tar.gz (6.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot-keras-history) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot-keras-history) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot-keras-history) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot-keras-history) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot-keras-history) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot-keras-history) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot-keras-history) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot-keras-history) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->plot-keras-history) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->plot-keras-history) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->plot-keras-history) (1.16.0)
# Building wheels for collected packages: plot-keras-history, sanitize_ml_labels, support_developer, compress_json
#   Building wheel for plot-keras-history (setup.py) ... done
#   Created wheel for plot-keras-history: filename=plot_keras_history-1.1.38-py3-none-any.whl size=9455 sha256=9785635d40499dc9c4cafc757e115bf7c5001e3a6ab2c4209a6f4ea522951eeb
#   Stored in directory: /root/.cache/pip/wheels/2f/31/6c/bbc9703b7baa8bd3802a8aedd9e2f9e66941b0cf0d456ab4cc
#   Building wheel for sanitize_ml_labels (setup.py) ... done
#   Created wheel for sanitize_ml_labels: filename=sanitize_ml_labels-1.0.51-py3-none-any.whl size=321865 sha256=f4c4aef5efc4e6a487de2343485846ae746bc4c2692c65833cbfe11a41f27ee6
#   Stored in directory: /root/.cache/pip/wheels/30/9f/f5/37d037c39ac8b305590d5956f7021c6ca94b63c68be24f6841
#   Building wheel for support_developer (setup.py) ... done
#   Created wheel for support_developer: filename=support_developer-1.0.5-py3-none-any.whl size=5630 sha256=828ce9467076cf0bb1ac1768d002a9b4fed44fffa0c8029dc918ac055facf891
#   Stored in directory: /root/.cache/pip/wheels/b6/72/c8/3054a5897ba0713dfa7a941364d68cbd42b0755c8e2ec1c18c
#   Building wheel for compress_json (setup.py) ... done
#   Created wheel for compress_json: filename=compress_json-1.0.10-py3-none-any.whl size=5817 sha256=6bb08905156e5b156972bdbfe7054852a720535da36d6c82c4ef0c701584d37d
#   Stored in directory: /root/.cache/pip/wheels/7b/55/94/bc79987b855aac5990e0d015c2e604aa50bc5147673e98530c
# Successfully built plot-keras-history sanitize_ml_labels support_developer compress_json
# Installing collected packages: support_developer, compress_json, sanitize_ml_labels, plot-keras-history
# Successfully installed compress_json-1.0.10 plot-keras-history-1.1.38 sanitize_ml_labels-1.0.51 support_developer-1.0.5

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.callbacks import EarlyStopping

# %matplotlib inline
from plot_keras_history import plot_history
import matplotlib.pyplot as plt


# %matplotlib inline
from plot_keras_history import plot_history
import matplotlib.pyplot as plt

# %%
# 구글 드라이브에 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # STEP 1: 데이터 Load & 전처리

# %%
path ='/content/drive/MyDrive/Colab Notebooks/딥러닝으로 걷는 시계열 예측/'
kospi200 = np.load(path + 'data/kospi200.npy')
samsung = np.load(path + 'data/samsung.npy')

# %%
display(kospi200.shape)
display(samsung.shape)
# Out:
# (426, 5)
# (426, 5)

# %%
samsung
# Out:
# array([[   53000.,    53900.,    51800.,    51900., 39565391.],
#        [   52600.,    53200.,    51900.,    52600., 23104720.],
#        [   52600.,    52800.,    50900.,    50900., 16128305.],
#        ...,
#        [   59100.,    59700.,    58800.,    59100., 16446102.],
#        [   58800.,    58800.,    56800.,    57200., 20821939.],
#        [   57800.,    58400.,    56400.,    56400., 19749457.]])

# %%
def split_xy5(dataset,time_steps,y_column):
    x,y=list(),list()
    for i in range(len(dataset)):
        x_end_number = i+time_steps
        y_end_number = x_end_number+y_column

        if y_end_number > len(dataset):
            break

        tmp_x = dataset[i:x_end_number,:]
        tmp_y = dataset[x_end_number:y_end_number,3]

        x.append(tmp_x)
        y.append(tmp_y)
    return np.array(x),np.array(y)

# time_steps는 5개씩 학습
# y_columns은 target값이 몇번째 변수인지
x,y=split_xy5(samsung,5,1)

# %%
print(x[0,:],"\n",y[0])
print(x.shape)
print(y.shape)
# Out:
# [[   53000.    53900.    51800.    51900. 39565391.]
#  [   52600.    53200.    51900.    52600. 23104720.]
#  [   52600.    52800.    50900.    50900. 16128305.]
#  [   51700.    51700.    50600.    51600. 13905263.]
#  [   52000.    52200.    51200.    51300. 10314997.]]
#  [50100.]
# (421, 5, 5)
# (421, 1)

# %%
# train, test 나누기
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=1,test_size=0.3)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (294, 5, 5)
# (127, 5, 5)
# (294, 1)
# (127, 1)

# %%
# StandardScaler를 사용해서 전처리
# StandardScaler는 2차원 구조만 받으므로 reshape 필요
x_train = np.reshape(x_train,
    (x_train.shape[0], x_train.shape[1] * x_train.shape[2]))
x_test = np.reshape(x_test,
    (x_test.shape[0], x_test.shape[1] * x_test.shape[2]))
print(x_train.shape)
print(x_test.shape)
# Out:
# (294, 25)
# (127, 25)

# %%
# StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)
print(x_train_scaled[0,:])
# Out:
# [ 1.13392563  1.07633086  1.02393741  0.93187013 -0.028819    1.05994459
#   1.04756614  1.06686328  0.94933344  1.53138774  0.79093879  0.80213886
#   0.84540479  0.81507608  0.10811605  0.73712199  0.68893234  0.71073997
#   0.69657856  0.37360361  0.85647275  0.80021877  0.80910994  0.69442952
#  -0.16973555]

# %%
# (None,25)로 reshape한걸 다시 (None,5,5)로 reshape해주기
# 2차원 -> 3차원으로 다시 바꿔주기
# DNN과 input이 달라지는 부분
# RNN은 DNN과 다르게 데이터가 3차원이고 input으로 들어갈 땐 2차원
x_train_scaled = np.reshape(x_train_scaled,
 (x_train_scaled.shape[0],5,5))
x_test_scaled = np.reshape(x_test_scaled,
 (x_test_scaled.shape[0],5,5))

print(x_train_scaled.shape)
print(x_test_scaled.shape)
# Out:
# (294, 5, 5)
# (127, 5, 5)

# %% [markdown]
# # STEP 2: 다:1모델 LSTM

# %%
# 모델 구성
model = Sequential()
model.add(LSTM(64, input_shape=(5,5)))
model.add(Dense(32, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1))

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mse'])

early_stopping = EarlyStopping(patience=20)

history_model = model.fit(x_train_scaled,y_train,validation_split=0.2,verbose=1,
                          batch_size=1,epochs=100,callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 235/235 [==============================] - 13s 18ms/step - loss: 790034.1875 - mse: 790034.1875 - val_loss: 575819.1250 - val_mse: 575819.1250
# Epoch 2/100
# 235/235 [==============================] - 1s 6ms/step - loss: 3159372.7500 - mse: 3159372.7500 - val_loss: 817486.4375 - val_mse: 817486.4375
# Epoch 3/100
# 235/235 [==============================] - 2s 8ms/step - loss: 639898.8750 - mse: 639898.8750 - val_loss: 835900.9375 - val_mse: 835900.9375
# Epoch 4/100
# 235/235 [==============================] - 2s 8ms/step - loss: 608499.9375 - mse: 608499.9375 - val_loss: 684195.5000 - val_mse: 684195.5000
# Epoch 5/100
# 235/235 [==============================] - 2s 8ms/step - loss: 591875.3750 - mse: 591875.3750 - val_loss: 817971.2500 - val_mse: 817971.2500
# Epoch 6/100
# 235/235 [==============================] - 1s 5ms/step - loss: 644162.7500 - mse: 644162.7500 - val_loss: 579172.5625 - val_mse: 579172.5625
# Epoch 7/100
# 235/235 [==============================] - 1s 6ms/step - loss: 887693.0625 - mse: 887693.0625 - val_loss: 567588.8125 - val_mse: 567588.8125
# Epoch 8/100
# 235/235 [==============================] - 1s 5ms/step - loss: 895066.2500 - mse: 895066.2500 - val_loss: 587825.8750 - val_mse: 587825.8750
# Epoch 9/100
# 235/235 [==============================] - 1s 5ms/step - loss: 710736.5000 - mse: 710736.5000 - val_loss: 1049576.3750 - val_mse: 1049576.3750
# Epoch 10/100
# 235/235 [==============================] - 1s 5ms/step - loss: 626581.6250 - mse: 626581.6250 - val_loss: 755625.9375 - val_mse: 755625.9375
# Epoch 11/100
# 235/235 [==============================] - 1s 5ms/step - loss: 604370.8125 - mse: 604370.8125 - val_loss: 577827.8125 - val_mse: 577827.8125
# Epoch 12/100
# 235/235 [==============================] - 1s 5ms/step - loss: 717616.1250 - mse: 717616.1250 - val_loss: 1028795.2500 - val_mse: 1028795.2500
# Epoch 13/100
# 235/235 [==============================] - 1s 5ms/step - loss: 686544.6875 - mse: 686544.6875 - val_loss: 575245.4375 - val_mse: 575245.4375
# Epoch 14/100
# 235/235 [==============================] - 2s 8ms/step - loss: 717987.2500 - mse: 717987.2500 - val_loss: 628035.5625 - val_mse: 628035.5625
# Epoch 15/100
# 235/235 [==============================] - 2s 8ms/step - loss: 585647.6875 - mse: 585647.6875 - val_loss: 994932.5000 - val_mse: 994932.5000
# Epoch 16/100
# 235/235 [==============================] - 2s 8ms/step - loss: 683329.6250 - mse: 683329.6250 - val_loss: 1681222.5000 - val_mse: 1681222.5000
# Epoch 17/100
# 235/235 [==============================] - 1s 5ms/step - loss: 599353.6250 - mse: 599353.6250 - val_loss: 1405467.1250 - val_mse: 1405467.1250
# Epoch 18/100
# 235/235 [==============================] - 1s 5ms/step - loss: 676680.3125 - mse: 676680.3125 - val_loss: 1255044.7500 - val_mse: 1255044.7500
# Epoch 19/100
# 235/235 [==============================] - 1s 5ms/step - loss: 704509.9375 - mse: 704509.9375 - val_loss: 868173.6250 - val_mse: 868173.6250
# Epoch 20/100
# 235/235 [==============================] - 1s 5ms/step - loss: 663725.1875 - mse: 663725.1875 - val_loss: 615085.6250 - val_mse: 615085.6250
# Epoch 21/100
# 235/235 [==============================] - 1s 5ms/step - loss: 728255.2500 - mse: 728255.2500 - val_loss: 568412.1875 - val_mse: 568412.1875
# Epoch 22/100
# 235/235 [==============================] - 1s 5ms/step - loss: 653702.2500 - mse: 653702.2500 - val_loss: 966295.7500 - val_mse: 966295.7500
# Epoch 23/100
# 235/235 [==============================] - 1s 5ms/step - loss: 660429.5625 - mse: 660429.5625 - val_loss: 987589.7500 - val_mse: 987589.7500
# Epoch 24/100
# 235/235 [==============================] - 1s 5ms/step - loss: 696206.5000 - mse: 696206.5000 - val_loss: 742130.8750 - val_mse: 742130.8750
# Epoch 25/100
# 235/235 [==============================] - 2s 8ms/step - loss: 615689.8125 - mse: 615689.8125 - val_loss: 725643.1250 - val_mse: 725643.1250
# Epoch 26/100
# 235/235 [==============================] - 2s 7ms/step - loss: 608755.1250 - mse: 608755.1250 - val_loss: 758164.3125 - val_mse: 758164.3125
# Epoch 27/100
# 235/235 [==============================] - 2s 8ms/step - loss: 725006.3750 - mse: 725006.3750 - val_loss: 806419.6875 - val_mse: 806419.6875

# %%
plot_history(history_model.history)
plt.show()
# plot_history(model.history, path = '(hist)CNN_raw.png')
# plt.close()

# %%
loss, mse = model.evaluate(x_test_scaled, y_test, batch_size=1)
print('loss: ',loss)
print('mse :', mse)
# Out:
# 127/127 [==============================] - 0s 2ms/step - loss: 897251.3125 - mse: 897251.3125
# loss:  897251.3125
# mse : 897251.3125

# %%
y_pred = model.predict(x_test_scaled)

for i in range(5):
    print('종가 : ', y_test[i], '/ 예측가 : ', y_pred[i])
# Out:
# 4/4 [==============================] - 0s 4ms/step
# 종가 :  [52200.] / 예측가 :  [53017.234]
# 종가 :  [41450.] / 예측가 :  [40006.4]
# 종가 :  [49650.] / 예측가 :  [54128.52]
# 종가 :  [44800.] / 예측가 :  [46155.78]
# 종가 :  [49500.] / 예측가 :  [49706.33]
